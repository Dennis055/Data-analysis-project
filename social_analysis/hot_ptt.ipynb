# %%
import requests
import time
import json
from bs4 import BeautifulSoup


PTT_URL = 'https://www.ptt.cc'

def get_web_page(url):
    resp = requests.get(
        url=url,
        cookies={'over18': '1'}  # 告知Server已回答過滿18歲的問題
    )
    if resp.status_code != 200:
        print('Invalid url:', resp.url)
        return None
    else:
        return resp.text


def get_articles(dom, date):
    soup = BeautifulSoup(dom, 'html5lib')

    # 取得上一頁的連結
    paging_div = soup.find('div', 'btn-group btn-group-paging')
    prev_url = paging_div.find_all('a')[1]['href']

    articles = []  # 儲存取得的文章資料
    divs = soup.find_all('div', 'r-ent')
    for d in divs:
        if d.find('div', 'date').text.strip() == date:  # 發文日期正確
            # 取得推文數
            push_count = 0
            push_str = d.find('div', 'nrec').text
            if push_str:
                try:
                    push_count = int(push_str)  # 轉換字串為數字
                except ValueError:
                    # 若轉換失敗，可能是'爆'或 'X1', 'X2', ...
                    # 若不是, 不做任何事，push_count 保持為 0
                    if push_str == '爆':
                        push_count = 99
                    elif push_str.startswith('X'):
                        push_count = -10
            base_url = 'https://www.ptt.cc'
            # 取得文章連結及標題
            if d.find('a'):  # 有超連結，表示文章存在，未被刪除
                href = d.find('a')['href']
                title = d.find('a').text
                author = d.find('div', 'author').text if d.find('div', 'author') else ''
                articles.append({
                    'title': title,
                    'href': base_url + href,
                    'push_count': push_count,
                    'author': author
                })
    return articles, prev_url


def get_author_ids(posts, pattern):
    ids = set()
    for post in posts:
        if pattern in post['author']:
            ids.add(post['author'])
    return ids

def hot():
    current_page = get_web_page(PTT_URL + '/bbs/Gossiping/index.html')
    if current_page:
        articles = []  # 全部的今日文章
        today = time.strftime("%m/%d").lstrip('0')  # 今天日期, 去掉開頭的 '0' 以符合 PTT 網站格式
        
        current_articles, prev_url = get_articles(current_page, today)  # 目前頁面的今日文章
        while current_articles:  # 若目前頁面有今日文章則加入 articles，並回到上一頁繼續尋找是否有今日文章
            articles += current_articles
            current_page = get_web_page(PTT_URL + prev_url)
            current_articles, prev_url = get_articles(current_page, today)

        # 印出所有不同的 5566 id
        # print(get_author_ids(articles, '5566'))

        # 儲存或處理文章資訊
        print('今天有', len(articles), '篇文章')
        threshold = 50
        print('熱門文章(> %d 推):' % (threshold))
        for a in articles:
            if int(a['push_count']) > threshold:
                print(a)
        with open('gossiping.json', 'w', encoding='utf-8') as f:
            json.dump(articles, f, indent=2, sort_keys=True, ensure_ascii=False)

# %%
time.strftime("%m/%d").lstrip('0')
# Out:
# '2/26'

# %%
hot()
# Out:
# 今天有 867 篇文章
# 熱門文章(> 50 推):
# {'title': '[臉書] 柯文哲', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551158486.A.2F8.html', 'push_count': 52, 'author': 'rickey1270'}
# {'title': 'Re: [新聞] 拒矮化!以色列全球市長會議 柯文哲「台灣', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551155999.A.322.html', 'push_count': 78, 'author': 'ERT312'}
# {'title': '[新聞] 中科院極機密運載火箭「麒麟專案」外洩！', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551156085.A.E65.html', 'push_count': 99, 'author': 'zeuga'}
# {'title': 'Re: [臉書] 赤燭', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551156534.A.E71.html', 'push_count': 68, 'author': 'artpoet'}
# {'title': '[新聞] 張安樂率眾抬棺到立院抗議 從載棺貨車上', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551155845.A.327.html', 'push_count': 73, 'author': 'helikon'}
# {'title': '[新聞] 推出第七日 《還願》全球下架', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551155628.A.E53.html', 'push_count': 57, 'author': 'killerken'}
# {'title': 'Re: [新聞] 拒矮化!以色列全球市長會議 柯文哲「台灣', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551154809.A.F88.html', 'push_count': 76, 'author': 'alex10282'}
# {'title': '[新聞] 白狼抬棺率眾衝立法院抗議\u3000一失足慘摔入', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551154251.A.D6D.html', 'push_count': 99, 'author': 'sober716'}
# {'title': '[爆卦] 寶路總裁(?)張安樂自摔進棺材(影片)', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551154132.A.D12.html', 'push_count': 99, 'author': 'tysh710320'}
# {'title': 'Re: [新聞] 拒矮化!以色列全球市長會議 柯文哲「台灣', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551153782.A.E42.html', 'push_count': 89, 'author': 'ji3sie'}
# {'title': '[問卦] 跪求幫熱壓吐司攤位取名', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551153122.A.530.html', 'push_count': 99, 'author': 'Mackle84'}
# {'title': '[新聞] 維尼震怒？傳《還願》中國代理商破產還被', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551152751.A.7A1.html', 'push_count': 99, 'author': 'runa2'}
# {'title': '[新聞] 《還願》火紅 BBC:台灣遊戲用小熊維尼傷', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551152126.A.E25.html', 'push_count': 60, 'author': 'wenjames'}
# {'title': '[新聞] 拒矮化!以色列全球市長會議 柯文哲「台灣', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551151416.A.3D6.html', 'push_count': 99, 'author': 'kenny468'}
# {'title': '[爆卦] 韓流發威！高雄空品指數冠全臺', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551151492.A.1E3.html', 'push_count': 99, 'author': 'punkdog'}
# {'title': '[問卦] 為何臺灣不推廣吃兔肉？', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551150721.A.6B3.html', 'push_count': 57, 'author': 'asd8604'}
# {'title': '[臉書] 陳其邁 Chen Chi-Mai', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551149448.A.63F.html', 'push_count': 99, 'author': 'cheinshin'}
# {'title': '[新聞] 壓力大？\u3000男搭電聯車遭婦人「跳針」飆罵', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551149886.A.37D.html', 'push_count': 95, 'author': 'Desire5566'}
# {'title': '[新聞] 疑雲重重！《還願》買不到了\u3000赤燭聲明：主動下架', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551147899.A.301.html', 'push_count': 99, 'author': 'MayorKoWenJe'}
# {'title': '[新聞] 前國台辦官員：國民黨一中各表不是真「九', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551147208.A.2D4.html', 'push_count': 55, 'author': 'xuein'}
# {'title': '[問卦] 韓國愚蠢到想和共產黨簽和平協議？', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551147282.A.D5E.html', 'push_count': 88, 'author': 'hahaWenZuhah'}
# {'title': '[問卦] 28歲當到上校有可能嗎?', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551146509.A.FF2.html', 'push_count': 99, 'author': 'horse5566lee'}
# {'title': '[新聞] 國民黨的一中各表不是真正的「九二共識」', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551145173.A.C54.html', 'push_count': 54, 'author': 'butt1106'}
# {'title': '[新聞]批韓滿口謊言 何景榮:難道宴請穆斯林的吉', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551144821.A.750.html', 'push_count': 71, 'author': 'linhu8883324'}
# {'title': '[問卦] 離職當天做什麼才不會後悔', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551144985.A.EA7.html', 'push_count': 66, 'author': 'RiverEdge'}
# {'title': '[新聞] 公假新定義？韓國瑜體力不支在家睡\u3000市政', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551144196.A.2B1.html', 'push_count': 78, 'author': 'berlin5566'}
# {'title': '[新聞] 韓國瑜在家睡覺 高雄市政會議寫「公出」', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551142304.A.AC6.html', 'push_count': 99, 'author': 'opica'}
# {'title': '[新聞] 姚文智敗選後神隱\u3000轉行要拍紀錄片', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551140803.A.C08.html', 'push_count': 95, 'author': 'if2'}
# {'title': '[爆卦] 周錫瑋宣布參加kmt總統初選', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551141407.A.971.html', 'push_count': 99, 'author': 'agold'}
# {'title': '[問卦] 有鄉民家以前很有錢 然後賭博敗光的嗎?', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551140315.A.C0A.html', 'push_count': 68, 'author': 'chengyou66'}
# {'title': '[臉書] 赤燭', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551138543.A.B4B.html', 'push_count': 99, 'author': 'Zeelandia'}
# {'title': '[新聞] 酒駕致死63.7％判刑低於最低本刑 綠委：', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551131883.A.E28.html', 'push_count': 99, 'author': 'Workforme'}
# {'title': '[新聞] 不顧北京反對\u3000兩美艦昨再度穿越台海', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551133621.A.EDA.html', 'push_count': 78, 'author': 'Waitaha'}
# {'title': '[爆卦] 你們STEAM找得到還願嗎？', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551122274.A.834.html', 'push_count': 99, 'author': 'Lahaluto'}
# {'title': 'Re: [問卦] 還願的結局是??不懂!!', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551123006.A.6AE.html', 'push_count': 59, 'author': 'MagicYif'}
# {'title': 'Re: [爆卦] 還願上BBC啦!', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551116175.A.CBA.html', 'push_count': 72, 'author': 'CS5566'}
# {'title': '[問卦] 聽說還願中國代理商破產了', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551116453.A.172.html', 'push_count': 59, 'author': 'Montana01'}
# {'title': '[新聞] 農委會坦承，馬立克疫苗出包影響50萬蛋雞', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551116694.A.4E9.html', 'push_count': 95, 'author': 'r5e97nk63'}
# {'title': '[爆卦] 還願上BBC啦!', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551115396.A.2D0.html', 'push_count': 99, 'author': 'ousapas'}
# {'title': 'Re: [問卦] 資工系課程為何不強調逆練?', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551113900.A.723.html', 'push_count': 99, 'author': 'jserv'}
# {'title': '[新聞] 直播3小時玩破關 蘇內閣成《還願》內閣 ', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551112122.A.FB7.html', 'push_count': 56, 'author': 'Boner'}
# {'title': 'Re: [Gossiping] 看板 選情報導', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551112205.A.9DD.html', 'push_count': 99, 'author': 'gn02022222'}
# {'title': '[問卦] 幾歲開始發現吃到飽根本是邪魔歪道？', 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1551112582.A.5AF.html', 'push_count': 99, 'author': 'kerkers'}
